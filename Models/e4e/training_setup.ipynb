# %% [markdown]
# ### Configurations:
#
# To run a successfull training one needs to prepare multiple things:
#
# 1. Create a custom training and test set using `e4e_dataset_preparation.ipynb`
# 2. Convert the trained StyleGAN2-Ada weight from the official NVIDIA implementation to StyleGAN2 weights compatible with rosinality's implementations
# 3. Load all the necessary auxiliary models into the `Models/e4e/pretrained/` directory in the Data folder
# 4. Adapt all the paths in `configs/paths_config.py` and `configs/data_configs.py` to the custom training data and the model paths

# %%
import os
import pickle

# %%
os.chdir("../../encoder4editing/")

# %%
import numpy as np

model_path = "/pfs/work7/workspace/scratch/tu_zxmav84-thesis/Data.nosync/Models/e4e/pretrained/stylegan2_ada_zalando_germany.pt"
CMD =f"""
    python scripts/train.py \
    --dataset_type zalando_germany_encode \
    --exp_dir /pfs/work7/workspace/scratch/tu_zxmav84-thesis/Data.nosync/Models/e4e/test{np.random.randint(1000000)}/ \
    --start_from_latent_avg \
    --use_w_pool \
    --w_discriminator_lambda 0.1 \
    --progressive_start 20000 \
    --id_lambda 0.5 \
    --val_interval 10000 \
    --max_steps 200000 \
    --stylegan_size 512 \
    --stylegan_weights {model_path} \
    --workers 8 \
    --batch_size 8 \
    --test_batch_size 4 \
    --test_workers 4 \
"""
# !{CMD}
# Out:
# {'batch_size': 8,
#  'board_interval': 50,
#  'checkpoint_path': None,
#  'd_reg_every': 16,
#  'dataset_type': 'zalando_germany_encode',
#  'delta_norm': 2,
#  'delta_norm_lambda': 0.0002,
#  'encoder_type': 'Encoder4Editing',
#  'exp_dir': '/pfs/work7/workspace/scratch/tu_zxmav84-thesis/Data.nosync/Models/e4e/test649437/',
#  'id_lambda': 0.5,
#  'image_interval': 100,
#  'keep_optimizer': False,
#  'l2_lambda': 1.0,
#  'learning_rate': 0.0001,
#  'lpips_lambda': 0.8,
#  'lpips_type': 'alex',
#  'max_steps': 200000,
#  'optim_name': 'ranger',
#  'progressive_start': 20000,
#  'progressive_step_every': 2000,
#  'progressive_steps': [0,
#                        20000,
#                        22000,
#                        24000,
#                        26000,
#                        28000,
#                        30000,
#                        32000,
#                        34000,
#                        36000,
#                        38000,
#                        40000,
#                        42000,
#                        44000,
#                        46000,
#                        48000],
#  'r1': 10,
#  'resume_training_from_ckpt': None,
#  'save_interval': None,
#  'save_training_data': False,
#  'start_from_latent_avg': True,
#  'stylegan_size': 512,
#  'stylegan_weights': '/pfs/work7/workspace/scratch/tu_zxmav84-thesis/Data.nosync/Models/e4e/pretrained/stylegan2_ada_zalando_germany.pt',
#  'sub_exp_dir': None,
#  'test_batch_size': 4,
#  'test_workers': 4,
#  'train_decoder': False,
#  'update_param_list': None,
#  'use_w_pool': True,
#  'val_interval': 10000,
#  'w_discriminator_lambda': 0.1,
#  'w_discriminator_lr': 2e-05,
#  'w_pool_size': 50,
#  'workers': 8}
# Loading encoders weights from irse50!
# Loading decoder weights from pretrained!
# Loading MOCO model from path: /pfs/work7/workspace/scratch/tu_zxmav84-thesis/Data.nosync/Models/e4e/pretrained/moco_v2_800ep_pretrain.pt
# Loading dataset for zalando_germany_encode
# Number of training samples: 11248
# Number of test samples: 2812
# Changed progressive stage to:  ProgressiveStage.WTraining
# ./training/ranger.py:123: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:882.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# Metrics for train, step 0
# 	d_real_loss =  0.705941915512085
# 	d_fake_loss =  0.6973575353622437
# 	discriminator_loss =  1.4032994508743286
# 	discriminator_r1_loss =  0.1646551489830017
# 	encoder_discriminator_loss =  0.6942093968391418
# 	total_delta_loss =  0.0
# 	loss_id =  0.2806275486946106
# 	id_improve =  -0.2806275263428688
# 	loss_l2 =  0.24991469085216522
# 	loss_lpips =  0.32227468490600586
# 	loss =  0.7174690961837769
# Metrics for train, step 50
# 	d_real_loss =  0.38294827938079834
# 	d_fake_loss =  0.49440768361091614
# 	discriminator_loss =  0.8773559331893921
# 	encoder_discriminator_loss =  0.9494718313217163
# 	total_delta_loss =  0.0
# 	loss_id =  0.24956999719142914
# 	id_improve =  -0.24957001581788063
# 	loss_l2 =  0.23685447871685028
# 	loss_lpips =  0.3168576955795288
# 	loss =  0.7100728154182434
# Metrics for train, step 100
# 	d_real_loss =  0.15765586495399475
# 	d_fake_loss =  0.17959457635879517
# 	discriminator_loss =  0.3372504413127899
# 	encoder_discriminator_loss =  1.8279414176940918
# 	total_delta_loss =  0.0
# 	loss_id =  0.23073315620422363
# 	id_improve =  -0.23073315620422363
# 	loss_l2 =  0.13981962203979492
# 	loss_lpips =  0.30040445923805237
# 	loss =  0.6783039569854736
# Metrics for train, step 150
# 	d_real_loss =  0.1084858775138855
# 	d_fake_loss =  0.056458912789821625
# 	discriminator_loss =  0.16494479775428772
# 	encoder_discriminator_loss =  2.909545421600342
# 	total_delta_loss =  0.0
# 	loss_id =  0.28570470213890076
# 	id_improve =  -0.28570469468832016
# 	loss_l2 =  0.1409815400838852
# 	loss_lpips =  0.31387612223625183
# 	loss =  0.8258893489837646
# Metrics for train, step 200
# 	d_real_loss =  0.09771187603473663
# 	d_fake_loss =  0.03683751821517944
# 	discriminator_loss =  0.13454939424991608
# 	encoder_discriminator_loss =  3.326347827911377
# 	total_delta_loss =  0.0
# 	loss_id =  0.24007907509803772
# 	id_improve =  -0.24007907509803772
# 	loss_l2 =  0.18571555614471436
# 	loss_lpips =  0.30141007900238037
# 	loss =  0.8795179724693298
# Metrics for train, step 250
# 	d_real_loss =  0.10102513432502747
# 	d_fake_loss =  0.09545999020338058
# 	discriminator_loss =  0.19648513197898865
# 	encoder_discriminator_loss =  2.8922386169433594
# 	total_delta_loss =  0.0
# 	loss_id =  0.23745658993721008
# 	id_improve =  -0.23745660483837128
# 	loss_l2 =  0.1687258929014206
# 	loss_lpips =  0.2996208369731903
# 	loss =  0.8163747787475586
# Metrics for train, step 300
# 	d_real_loss =  0.11681007593870163
# 	d_fake_loss =  0.06651639938354492
# 	discriminator_loss =  0.18332648277282715
# 	encoder_discriminator_loss =  2.8289828300476074
# 	total_delta_loss =  0.0
# 	loss_id =  0.26460087299346924
# 	id_improve =  -0.26460087299346924
# 	loss_l2 =  0.16204971075057983
# 	loss_lpips =  0.319945752620697
# 	loss =  0.8332051038742065
# Metrics for train, step 350
# 	d_real_loss =  0.09104220569133759
# 	d_fake_loss =  0.08489055931568146
# 	discriminator_loss =  0.17593276500701904
# 	encoder_discriminator_loss =  2.493140697479248
# 	total_delta_loss =  0.0
# 	loss_id =  0.2276187241077423
# 	id_improve =  -0.22761864960193634
# 	loss_l2 =  0.17016971111297607
# 	loss_lpips =  0.35862141847610474
# 	loss =  0.8201903104782104
# Metrics for train, step 400
# 	d_real_loss =  0.07517664134502411
# 	d_fake_loss =  0.09765581786632538
# 	discriminator_loss =  0.1728324592113495
# 	discriminator_r1_loss =  4.289566993713379
# 	encoder_discriminator_loss =  2.3281350135803223
# 	total_delta_loss =  0.0
# 	loss_id =  0.1644044816493988
# 	id_improve =  -0.1644044741988182
# 	loss_l2 =  0.08393945544958115
# 	loss_lpips =  0.2753455638885498
# 	loss =  0.619231641292572
# Metrics for train, step 450
# 	d_real_loss =  0.0957256555557251
# 	d_fake_loss =  0.12685281038284302
# 	discriminator_loss =  0.22257846593856812
# 	encoder_discriminator_loss =  2.0685977935791016
# 	total_delta_loss =  0.0
# 	loss_id =  0.1225920021533966
# 	id_improve =  -0.12259197235107422
# 	loss_l2 =  0.12596546113491058
# 	loss_lpips =  0.24434387683868408
# 	loss =  0.5895963311195374
# Metrics for train, step 500
# 	d_real_loss =  0.10350020229816437
# 	d_fake_loss =  0.1663692146539688
# 	discriminator_loss =  0.2698694169521332
# 	encoder_discriminator_loss =  1.8645344972610474
# 	total_delta_loss =  0.0
# 	loss_id =  0.14053624868392944
# 	id_improve =  -0.14053624868392944
# 	loss_l2 =  0.07568977773189545
# 	loss_lpips =  0.2977869510650635
# 	loss =  0.5706409215927124
# Metrics for train, step 550
# 	d_real_loss =  0.11632995307445526
# 	d_fake_loss =  0.18225662410259247
# 	discriminator_loss =  0.29858657717704773
# 	encoder_discriminator_loss =  1.7613131999969482
# 	total_delta_loss =  0.0
# 	loss_id =  0.15523207187652588
# 	id_improve =  -0.1552320495247841
# 	loss_l2 =  0.08305887132883072
# 	loss_lpips =  0.21297481656074524
# 	loss =  0.5071860551834106
# Metrics for train, step 600
# 	d_real_loss =  0.13443833589553833
# 	d_fake_loss =  0.17405837774276733
# 	discriminator_loss =  0.30849671363830566
# 	encoder_discriminator_loss =  1.8315207958221436
# 	total_delta_loss =  0.0
# 	loss_id =  0.13790227472782135
# 	id_improve =  -0.13790225982666016
# 	loss_l2 =  0.12445517629384995
# 	loss_lpips =  0.24372845888137817
# 	loss =  0.5715411901473999
# Metrics for train, step 650
# 	d_real_loss =  0.1204051822423935
# 	d_fake_loss =  0.18596653640270233
# 	discriminator_loss =  0.3063717186450958
# 	encoder_discriminator_loss =  1.7417768239974976
# 	total_delta_loss =  0.0
# 	loss_id =  0.1402977705001831
# 	id_improve =  -0.1402977854013443
# 	loss_l2 =  0.09437438100576401
# 	loss_lpips =  0.2522614002227783
# 	loss =  0.5405100584030151
# Metrics for train, step 700
# 	d_real_loss =  0.12340592592954636
# 	d_fake_loss =  0.20024633407592773
# 	discriminator_loss =  0.3236522674560547
# 	encoder_discriminator_loss =  1.6936044692993164
# 	total_delta_loss =  0.0
# 	loss_id =  0.22881323099136353
# 	id_improve =  -0.22881316393613815
# 	loss_l2 =  0.10052353143692017
# 	loss_lpips =  0.2648426294326782
# 	loss =  0.5961647033691406
# ^C
# Traceback (most recent call last):
#   File "scripts/train.py", line 88, in <module>
#     main()
#   File "scripts/train.py", line 29, in main
#     coach.train()
#   File "./training/coach.py", line 113, in train
#     loss_dict = self.train_discriminator(batch)
#   File "./training/coach.py", line 384, in train_discriminator
#     real_w, fake_w = self.sample_real_and_fake_latents(x)
#   File "./training/coach.py", line 433, in sample_real_and_fake_latents
#     fake_w = fake_w[:, dims_to_discriminate, :]
# KeyboardInterrupt
