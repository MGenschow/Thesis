# %% [markdown]
# ### Configurations:
#
# - To run a successfull training ...

# %%
import os
import pickle

# %%
os.chdir("../../encoder4editing/")

# %%
import numpy as np

model_path = "../Models/e4e/test.pt"
CMD =f"""
    python scripts/train.py \
    --dataset_type zalando_germany_encode \
    --exp_dir /pfs/work7/workspace/scratch/tu_zxmav84-thesis/Data.nosync/Models/e4e/test{np.random.randint(1000000)}/ \
    --start_from_latent_avg \
    --use_w_pool \
    --w_discriminator_lambda 0.1 \
    --progressive_start 20000 \
    --id_lambda 0.5 \
    --val_interval 10000 \
    --max_steps 200000 \
    --stylegan_size 512 \
    --stylegan_weights {model_path} \
    --workers 8 \
    --batch_size 8 \
    --test_batch_size 4 \
    --test_workers 4 \
"""
# !{CMD}
# Out:
# {'batch_size': 8,
#  'board_interval': 50,
#  'checkpoint_path': None,
#  'd_reg_every': 16,
#  'dataset_type': 'zalando_germany_encode',
#  'delta_norm': 2,
#  'delta_norm_lambda': 0.0002,
#  'encoder_type': 'Encoder4Editing',
#  'exp_dir': '/pfs/work7/workspace/scratch/tu_zxmav84-thesis/Data.nosync/Models/e4e/test651737/',
#  'id_lambda': 0.5,
#  'image_interval': 100,
#  'keep_optimizer': False,
#  'l2_lambda': 1.0,
#  'learning_rate': 0.0001,
#  'lpips_lambda': 0.8,
#  'lpips_type': 'alex',
#  'max_steps': 200000,
#  'optim_name': 'ranger',
#  'progressive_start': 20000,
#  'progressive_step_every': 2000,
#  'progressive_steps': [0,
#                        20000,
#                        22000,
#                        24000,
#                        26000,
#                        28000,
#                        30000,
#                        32000,
#                        34000,
#                        36000,
#                        38000,
#                        40000,
#                        42000,
#                        44000,
#                        46000,
#                        48000],
#  'r1': 10,
#  'resume_training_from_ckpt': None,
#  'save_interval': None,
#  'save_training_data': False,
#  'start_from_latent_avg': True,
#  'stylegan_size': 512,
#  'stylegan_weights': '../Models/e4e/test.pt',
#  'sub_exp_dir': None,
#  'test_batch_size': 4,
#  'test_workers': 4,
#  'train_decoder': False,
#  'update_param_list': None,
#  'use_w_pool': True,
#  'val_interval': 10000,
#  'w_discriminator_lambda': 0.1,
#  'w_discriminator_lr': 2e-05,
#  'w_pool_size': 50,
#  'workers': 8}
# Loading encoders weights from irse50!
# Loading decoder weights from pretrained!
# Loading MOCO model from path: /pfs/work7/workspace/scratch/tu_zxmav84-thesis/Data.nosync/Models/e4e/pretrained/moco_v2_800ep_pretrain.pt
# Loading dataset for zalando_germany_encode
# Number of training samples: 11248
# Number of test samples: 2812
# Changed progressive stage to:  ProgressiveStage.WTraining
# ./training/ranger.py:123: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:882.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# Metrics for train, step 0
# 	d_real_loss =  0.705941915512085
# 	d_fake_loss =  0.6973575353622437
# 	discriminator_loss =  1.4032994508743286
# 	discriminator_r1_loss =  0.1646551489830017
# 	encoder_discriminator_loss =  0.6942093968391418
# 	total_delta_loss =  0.0
# 	loss_id =  0.28062766790390015
# 	id_improve =  -0.28062760829925537
# 	loss_l2 =  0.24991469085216522
# 	loss_lpips =  0.32227468490600586
# 	loss =  0.7174692153930664
# Metrics for train, step 50
# 	d_real_loss =  0.38294756412506104
# 	d_fake_loss =  0.4943862557411194
# 	discriminator_loss =  0.8773338198661804
# 	encoder_discriminator_loss =  0.9495127201080322
# 	total_delta_loss =  0.0
# 	loss_id =  0.24956029653549194
# 	id_improve =  -0.24956028908491135
# 	loss_l2 =  0.23683926463127136
# 	loss_lpips =  0.31685367226600647
# 	loss =  0.7100536227226257
# Metrics for train, step 100
# 	d_real_loss =  0.15764287114143372
# 	d_fake_loss =  0.1795312464237213
# 	discriminator_loss =  0.33717411756515503
# 	encoder_discriminator_loss =  1.828301191329956
# 	total_delta_loss =  0.0
# 	loss_id =  0.23071777820587158
# 	id_improve =  -0.23071777820587158
# 	loss_l2 =  0.13964134454727173
# 	loss_lpips =  0.30029696226119995
# 	loss =  0.6780679225921631
# Metrics for train, step 150
# 	d_real_loss =  0.10848858952522278
# 	d_fake_loss =  0.05655324459075928
# 	discriminator_loss =  0.16504183411598206
# 	encoder_discriminator_loss =  2.906125068664551
# 	total_delta_loss =  0.0
# 	loss_id =  0.2858830988407135
# 	id_improve =  -0.2858830839395523
# 	loss_l2 =  0.1380440890789032
# 	loss_lpips =  0.31410694122314453
# 	loss =  0.8228837251663208
# Metrics for train, step 200
# 	d_real_loss =  0.09761571139097214
# 	d_fake_loss =  0.03621901571750641
# 	discriminator_loss =  0.13383471965789795
# 	encoder_discriminator_loss =  3.36370849609375
# 	total_delta_loss =  0.0
# 	loss_id =  0.2328188121318817
# 	id_improve =  -0.2328188195824623
# 	loss_l2 =  0.17741744220256805
# 	loss_lpips =  0.30612367391586304
# 	loss =  0.8750966787338257
# Metrics for train, step 250
# 	d_real_loss =  0.09875823557376862
# 	d_fake_loss =  0.06531272828578949
# 	discriminator_loss =  0.1640709638595581
# 	encoder_discriminator_loss =  3.1798367500305176
# 	total_delta_loss =  0.0
# 	loss_id =  0.232736274600029
# 	id_improve =  -0.23273629695177078
# 	loss_l2 =  0.1628609150648117
# 	loss_lpips =  0.2939828038215637
# 	loss =  0.8323990106582642
# Metrics for train, step 300
# 	d_real_loss =  0.12675663828849792
# 	d_fake_loss =  0.07450780272483826
# 	discriminator_loss =  0.20126444101333618
# 	encoder_discriminator_loss =  2.7927799224853516
# 	total_delta_loss =  0.0
# 	loss_id =  0.2801794409751892
# 	id_improve =  -0.2801794409751892
# 	loss_l2 =  0.15626275539398193
# 	loss_lpips =  0.3233354389667511
# 	loss =  0.834298849105835
# Metrics for train, step 350
# 	d_real_loss =  0.08999897539615631
# 	d_fake_loss =  0.086698979139328
# 	discriminator_loss =  0.17669795453548431
# 	encoder_discriminator_loss =  2.465426445007324
# 	total_delta_loss =  0.0
# 	loss_id =  0.31237006187438965
# 	id_improve =  -0.31237000972032547
# 	loss_l2 =  0.17892026901245117
# 	loss_lpips =  0.36718493700027466
# 	loss =  0.8753958940505981
# Metrics for train, step 400
# 	d_real_loss =  0.07820932567119598
# 	d_fake_loss =  0.11285510659217834
# 	discriminator_loss =  0.19106443226337433
# 	discriminator_r1_loss =  4.699833869934082
# 	encoder_discriminator_loss =  2.1996164321899414
# 	total_delta_loss =  0.0
# 	loss_id =  0.16154971718788147
# 	id_improve =  -0.16154969483613968
# 	loss_l2 =  0.085246741771698
# 	loss_lpips =  0.28019723296165466
# 	loss =  0.6101410388946533
# Metrics for train, step 450
# 	d_real_loss =  0.09618611633777618
# 	d_fake_loss =  0.13301195204257965
# 	discriminator_loss =  0.22919806838035583
# 	encoder_discriminator_loss =  2.020103931427002
# 	total_delta_loss =  0.0
# 	loss_id =  0.1618221402168274
# 	id_improve =  -0.161822110414505
# 	loss_l2 =  0.13243843615055084
# 	loss_lpips =  0.25862807035446167
# 	loss =  0.6222623586654663
# ^C
# Traceback (most recent call last):
#   File "scripts/train.py", line 88, in <module>
#     main()
#   File "scripts/train.py", line 29, in main
#     coach.train()
#   File "./training/coach.py", line 114, in train
#     x, y, y_hat, latent = self.forward(batch)
#   File "./training/coach.py", line 282, in forward
#     y_hat, latent = self.net.forward(x, return_latents=True)
#   File "./models/psp.py", line 84, in forward
#     return_latents=return_latents)
#   File "/pfs/work7/workspace/scratch/tu_zxmav84-thesis/miniconda3/envs/thesis/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "./models/stylegan2/model.py", line 529, in forward
#     out = conv1(out, latent[:, i], noise=noise1)
#   File "/pfs/work7/workspace/scratch/tu_zxmav84-thesis/miniconda3/envs/thesis/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "./models/stylegan2/model.py", line 332, in forward
#     out = self.conv(input, style)
#   File "/pfs/work7/workspace/scratch/tu_zxmav84-thesis/miniconda3/envs/thesis/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "./models/stylegan2/model.py", line 257, in forward
#     out = self.blur(out)
#   File "/pfs/work7/workspace/scratch/tu_zxmav84-thesis/miniconda3/envs/thesis/lib/python3.7/site-packages/torch/nn/modules/module.py", line 727, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "./models/stylegan2/model.py", line 85, in forward
#     out = upfirdn2d(input, self.kernel, pad=self.pad)
#   File "./models/stylegan2/op/upfirdn2d.py", line 144, in upfirdn2d
#     input, kernel, (up, up), (down, down), (pad[0], pad[1], pad[0], pad[1])
#   File "./models/stylegan2/op/upfirdn2d.py", line 98, in forward
#     ctx.save_for_backward(kernel, torch.flip(kernel, [0, 1]))
# KeyboardInterrupt
