# %%
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# %%
images_path = '../../../Data.nosync/Zalando_UK_Dataset/dresses/images/raw_images/'

# %%
df = pd.read_json('../../../Data.nosync/Zalando_UK_Dataset/dresses/metadata/dresses_metadata.json').T.reset_index().rename(columns = {'index':'ID'})
df
# Out:
#                  ID                                                url  \
# 0     GE221C0GK-K11  https://www.zalando.co.uk/gestuz-frilly-long-d...
# 1     ON321C3EU-K11  https://www.zalando.co.uk/only-onlrouge-34-rin...
# 2     TOB21C0CD-K11  https://www.zalando.co.uk/tommy-jeans-slim-bel...
# 3     TOB21C0AY-K11  https://www.zalando.co.uk/tommy-jeans-badge-mi...
# 4     H7C21C005-O11  https://www.zalando.co.uk/hermanandco-denim-dr...
# ...             ...                                                ...
# 3233  HU721C0O8-J11  https://www.zalando.co.uk/hugo-nassari-day-dre...
# 3234  LAR21C05I-O11  https://www.zalando.co.uk/lauren-ralph-lauren-...
# 3235  L4221C1RD-C11  https://www.zalando.co.uk/lauren-ralph-lauren-...
# 3236  A0F21C0EE-C11  https://www.zalando.co.uk/abercrombie-and-fitc...
# 3237  6CA21C09N-B11  https://www.zalando.co.uk/calvin-klein-mini-ta...
#
#                            brand garment_type  color  fabric          fit  \
# 0                         Gestuz  denim_dress   blue   Denim     Slim Fit
# 1                           ONLY  denim_dress   grey   Denim     Slim Fit
# 2                    Tommy Jeans  denim_dress   blue   Denim  Regular Fit
# 3                    Tommy Jeans  denim_dress   blue   Denim  Regular Fit
# 4                      HERMAN&CO  denim_dress  brown   Denim  Regular Fit
# ...                          ...          ...    ...     ...          ...
# 3233                        HUGO   work_dress    red  Jersey     Slim Fit
# 3234  Lauren Ralph Lauren Petite   work_dress  brown  Jersey     Slim Fit
# 3235         Lauren Ralph Lauren   work_dress  brown    None     Slim Fit
# 3236         Abercrombie & Fitch   work_dress   grey    None     Slim Fit
# 3237                Calvin Klein   work_dress  beige  Jersey     Slim Fit
#
#             neckline pattern            collar       length
# 0           Backless    None   Standing Collar         Long
# 1               None   Plain  Turn-down Collar        Short
# 2               None   Plain  Turn-down Collar        Short
# 3               None    None  Turn-down Collar        Short
# 4               None   Plain  Turn-down Collar        Short
# ...              ...     ...               ...          ...
# 3233       Crew neck   Plain              None        Short
# 3234            None   Plain   Standing Collar  Knee-length
# 3235       Crew neck   Other              None  Knee-length
# 3236  Low-cut v-neck    Marl              None  Extra short
# 3237       Crew neck   Plain              None        Short
#
# [3238 rows x 11 columns]

# %%
def plot_category_counts(cat):
    fig, ax = plt.subplots(figsize = (6,3))
    with plt.style.context("fivethirtyeight"):
        df[cat].value_counts(dropna = False).plot(kind = 'bar', ax = ax)
        plt.title(f'Counts of {cat}')
        plt.xticks(rotation=45)
        plt.show()

def plot_samples(cat):
    cat_values = df[cat].unique().tolist()
    fig, ax = plt.subplots(1, len(cat_values), figsize = (30,5))
    for i, category in enumerate(cat_values):
        sub_df = df[df[cat] == category]
        if sub_df.shape[0] != 0:
            img_path = sub_df.sample(1).ID.item()
            img = Image.open(images_path + img_path + '.jpg')
            ax[i].imshow(img)
        ax[i].axis('off')
        ax[i].set_title(category)

# %% [markdown]
# ### Brands

# %%
df.brand.nunique()
# Out:
# 299

# %%
df.brand.value_counts().sort_values(ascending = False).head(10)
# Out:
# brand
# WAL G.                 147
# Mango                  123
# ONLY                    85
# b.young                 77
# Vero Moda               73
# Lauren Ralph Lauren     68
# Fransa                  64
# YAS                     56
# VILA                    56
# ICHI                    56
# Name: count, dtype: int64

# %% [markdown]
# ### Garment Type

# %%
plot_category_counts('garment_type')

# %%
plot_samples('garment_type')

# %% [markdown]
# ### Color

# %%
plot_category_counts('color')

# %%
plot_samples('color')

# %% [markdown]
# ### Fabric

# %%
plot_category_counts('fabric')

# %%
plot_samples('fabric')

# %% [markdown]
# ### Pattern

# %%
plot_category_counts('pattern')

# %%
plot_samples('pattern')

# %% [markdown]
# ### Collar

# %%
plot_category_counts('collar')

# %%
plot_samples('collar')

# %% [markdown]
# ### Length

# %%
plot_category_counts('length')

# %%
plot_samples('length')
