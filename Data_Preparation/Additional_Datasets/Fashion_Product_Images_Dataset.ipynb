# %% [markdown]
# ### Download Files and Unzip

# %%
# # Download dataset
# !kaggle datasets download paramaggarwal/fashion-product-images-dataset -p ../../../Data.nosync/Fashion_Product_Images_Dataset
# # Unzip dataset
# !unzip ../../../Data.nosync/Fashion_Product_Images_Dataset/fashion-product-images-dataset.zip -d ../../../Data.nosync/Fashion_Product_Images_Dataset/Raw_Data

# %% [markdown]
# ### Data Checks

# %%
import pandas as pd
df = pd.read_csv('/Users/maltegenschow/Downloads/styles.csv', on_bad_lines='skip')

# %%
df.articleType.value_counts().head(30)
# Out:
# articleType
# Tshirts                  7067
# Shirts                   3217
# Casual Shoes             2845
# Watches                  2542
# Sports Shoes             2036
# Kurtas                   1844
# Tops                     1762
# Handbags                 1759
# Heels                    1323
# Sunglasses               1073
# Wallets                   936
# Flip Flops                914
# Sandals                   897
# Briefs                    849
# Belts                     813
# Backpacks                 724
# Socks                     686
# Formal Shoes              637
# Perfume and Body Mist     613
# Jeans                     609
# Shorts                    547
# Trousers                  530
# Flats                     500
# Bra                       477
# Dresses                   464
# Sarees                    427
# Earrings                  416
# Deodorant                 347
# Nail Polish               329
# Lipstick                  315
# Name: count, dtype: int64

# %%
df[df.articleType == 'Dresses']
# Out:
#           id gender masterCategory subCategory articleType baseColour  season  \
# 94     39716  Women        Apparel       Dress     Dresses       Blue  Summer
# 305     4988  Women        Apparel       Dress     Dresses      White  Summer
# 536    31127  Girls        Apparel       Dress     Dresses      Black  Summer
# 599    10406  Women        Apparel       Dress     Dresses       Grey    Fall
# 774     6873  Women        Apparel       Dress     Dresses      Black  Summer
# ...      ...    ...            ...         ...         ...        ...     ...
# 43423   4936  Women        Apparel       Dress     Dresses      Black  Summer
# 43458   2699  Girls        Apparel       Dress     Dresses       Pink  Summer
# 43967  59811  Women        Apparel       Dress     Dresses      Beige    Fall
# 44359   2697  Girls        Apparel       Dress     Dresses       Blue  Summer
# 44368  37267  Girls        Apparel       Dress     Dresses        Red  Summer
#
#          year   usage                                 productDisplayName
# 94     2012.0  Casual                       Arrow Woman Women Blue Dress
# 305    2011.0  Casual  Gini and Jony Girl's Vanya White Polka Dot Kid...
# 536    2012.0  Casual                    Gini and Jony Girls Black Dress
# 599    2011.0  Casual  United Colors of Benetton Women Solid Grey Dre...
# 774    2011.0  Casual                Forever New Women's Top Black Dress
# ...       ...     ...                                                ...
# 43423  2011.0  Casual  Gini and Jony Girl's Veata White Black Pink In...
# 43458  2011.0  Casual  Disney Kids Girls Disney girl pink pooh top Ki...
# 43967  2012.0  Casual  United Colors of Benetton Women Beige Printed ...
# 44359  2011.0  Casual              Disney Kids Girl's Blue Pooh Kidswear
# 44368  2012.0  Casual  United Colors of Benetton Girls Red Printed Dress
#
# [464 rows x 10 columns]
