# %%
import os 
os.chdir("../../restyle-encoder/")

# %%
CMD = """python scripts/train_restyle_e4e.py \
    --dataset_type=zalando_germany_encode \
    --encoder_type=ResNetProgressiveBackboneEncoder \
    --exp_dir=/pfs/work7/workspace/scratch/tu_zxmav84-thesis/Data.nosync/Models/restyle/setup_test/ \
    --stylegan_weights /pfs/work7/workspace/scratch/tu_zxmav84-thesis/Data.nosync/Models/hyperstyle/pretrained/00005-stylegan2_ada_images-mirror-auto2-kimg5000-resumeffhq512_network-snapshot-001200.pt \
    --workers=8 \
    --batch_size=8 \
    --test_batch_size=8 \
    --test_workers=8 \
    --val_interval=2000 \
    --image_interval=500 \
    --save_interval=2000 \
    --start_from_latent_avg \
    --lpips_lambda=0.8 \
    --l2_lambda=1 \
    --w_norm_lambda=0 \
    --id_lambda=0 \
    --moco_lambda=0.5 \
    --input_nc=6 \
    --n_iters_per_batch=5 \
    --output_size=512 \
    --save_training_data
"""
# !{CMD}
# Out:
# {'batch_size': 8,
#  'board_interval': 50,
#  'checkpoint_path': None,
#  'd_reg_every': 16,
#  'dataset_type': 'zalando_germany_encode',
#  'delta_norm': 2,
#  'delta_norm_lambda': 0.0002,
#  'encoder_type': 'ResNetProgressiveBackboneEncoder',
#  'exp_dir': '/pfs/work7/workspace/scratch/tu_zxmav84-thesis/Data.nosync/Models/restyle/setup_test/',
#  'id_lambda': 0.0,
#  'image_interval': 500,
#  'input_nc': 6,
#  'l2_lambda': 1.0,
#  'learning_rate': 0.0001,
#  'lpips_lambda': 0.8,
#  'max_steps': 500000,
#  'moco_lambda': 0.5,
#  'n_iters_per_batch': 5,
#  'optim_name': 'ranger',
#  'output_size': 512,
#  'progressive_start': None,
#  'progressive_step_every': 2000,
#  'progressive_steps': None,
#  'r1': 10,
#  'resume_training_from_ckpt': None,
#  'save_interval': 2000,
#  'save_training_data': True,
#  'start_from_latent_avg': True,
#  'stylegan_weights': '/pfs/work7/workspace/scratch/tu_zxmav84-thesis/Data.nosync/Models/hyperstyle/pretrained/00005-stylegan2_ada_images-mirror-auto2-kimg5000-resumeffhq512_network-snapshot-001200.pt',
#  'sub_exp_dir': None,
#  'test_batch_size': 8,
#  'test_workers': 8,
#  'train_decoder': False,
#  'update_param_list': None,
#  'use_w_pool': False,
#  'val_interval': 2000,
#  'w_discriminator_lambda': 0,
#  'w_discriminator_lr': 2e-05,
#  'w_norm_lambda': 0.0,
#  'w_pool_size': 50,
#  'workers': 8}
# Loading encoders weights from resnet34!
# Loading decoder weights from pretrained path: /pfs/work7/workspace/scratch/tu_zxmav84-thesis/Data.nosync/Models/hyperstyle/pretrained/00005-stylegan2_ada_images-mirror-auto2-kimg5000-resumeffhq512_network-snapshot-001200.pt
# Loading MOCO model from path: /pfs/work7/workspace/scratch/tu_zxmav84-thesis/Data.nosync/Models/hyperstyle/pretrained/moco_v2_800ep_pretrain.pt
# Loading dataset for zalando_germany_encode
# Number of training samples: 12654
# Number of test samples: 1406
# ./training/ranger.py:123: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:882.)
#   exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
# Metrics for train, step 0
# 	loss_l2 =  0.20953571796417236
# 	loss_lpips =  0.34147393703460693
# 	loss_moco =  0.30135437846183777
# 	id_improve =  -0.301354356110096
# 	loss =  0.6333920359611511
# ^C
# Traceback (most recent call last):
#   File "scripts/train_restyle_e4e.py", line 85, in <module>
#     main()
#   File "scripts/train_restyle_e4e.py", line 29, in main
#     coach.train()
#   File "./training/coach_restyle_e4e.py", line 161, in train
#     y_hats, encoder_loss_dict, id_logs = self.perform_train_iteration_on_batch(x, y)
#   File "./training/coach_restyle_e4e.py", line 141, in perform_train_iteration_on_batch
#     loss.backward()
#   File "/pfs/work7/workspace/scratch/tu_zxmav84-thesis/miniconda3/envs/thesis/lib/python3.7/site-packages/torch/tensor.py", line 221, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph)
#   File "/pfs/work7/workspace/scratch/tu_zxmav84-thesis/miniconda3/envs/thesis/lib/python3.7/site-packages/torch/autograd/__init__.py", line 132, in backward
#     allow_unreachable=True)  # allow_unreachable flag
# KeyboardInterrupt
